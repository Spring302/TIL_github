# %%
import sys
import pyautogui

# %%
def active():
    pyautogui.sleep(1)
    window = pyautogui.getWindowsWithTitle("NoxPlayer")[0]
    # window.maximize()
    window.activate()
    # print(window.size)
    ## Size(width=1014, height=581) 기준

active()
# Out:
# ---------------------------------------------------------------------------
# PyGetWindowException                      Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_23276/2154222964.py in <module>
#       7     ## Size(width=1014, height=581) 기준
#       8
# ----> 9 active()
#
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_23276/2154222964.py in active()
#       3     window = pyautogui.getWindowsWithTitle("NoxPlayer")[0]
#       4     # window.maximize()
# ----> 5     window.activate()
#       6     # print(window.size)
#       7     ## Size(width=1014, height=581) 기준
#
# C:\Python38-64\lib\site-packages\pygetwindow\_pygetwindow_win.py in activate(self)
#     244         result = ctypes.windll.user32.SetForegroundWindow(self._hWnd)
#     245         if result == 0:
# --> 246             _raiseWithLastError()
#     247
#     248
#
# C:\Python38-64\lib\site-packages\pygetwindow\_pygetwindow_win.py in _raiseWithLastError()
#      97     information from GetLastError() and FormatMessage()."""
#      98     errorCode = ctypes.windll.kernel32.GetLastError()
# ---> 99     raise PyGetWindowException('Error code from Windows: %s - %s' % (errorCode, _formatMessage(errorCode)))
#     100
#     101
#
# PyGetWindowException: Error code from Windows: 0 - 작업을 완료했습니다.

# %%
## 데이터 초기화
# icon_nier = pyautogui.locateOnScreen("icon_nier.png", confidence=0.7)
# pyautogui.mouseDown(icon_nier, duration=0.5)
# pyautogui.sleep(1)
# pyautogui.mouseUp()
# icon_nier = pyautogui.locateOnScreen("nier_app_info.png", confidence=0.7)
# pyautogui.click(icon_nier, duration=0.5)
# pyautogui.sleep(1)
# icon_nier = pyautogui.locateOnScreen("nier_app_info2.png", confidence=0.7)
# pyautogui.moveTo(icon_nier, duration=0.5)
# pyautogui.click(icon_nier, duration=0.5)
# pyautogui.sleep(1)
# icon_nier = pyautogui.locateOnScreen("nier_app_info3.png", confidence=0.7)
# pyautogui.moveTo(icon_nier, duration=0.5)
# pyautogui.click(icon_nier, duration=0.5)

## 게임 시작
# icon_nier = pyautogui.locateOnScreen("icon_nier.png", confidence=0.7)
# pyautogui.click(icon_nier, duration=0.5)
# pyautogui.sleep(1)

# icon_nier = pyautogui.locateOnScreen("nier_agree.png", confidence=0.7)
# pyautogui.click(icon_nier, duration=0.5)
# pyautogui.sleep(1)

# icon_nier = pyautogui.locateOnScreen("nier_yes.png", confidence=0.7)
# pyautogui.click(icon_nier, duration=0.5)
# pyautogui.sleep(1)

# icon_nier = pyautogui.locateOnScreen("nier_yes.png", confidence=0.7)
# pyautogui.click(icon_nier, duration=0.5)
# pyautogui.sleep(1)
# while True :
#     icon_nier = pyautogui.locateOnScreen("nier_yes.png", confidence=0.7)
#     if icon_nier:
#         pyautogui.click(icon_nier, duration=0.5)
#         break
#     pyautogui.sleep(1)
# while True :
#     icon_nier = pyautogui.locateOnScreen("nier_yes.png", confidence=0.7)
#     if icon_nier:
#         pyautogui.click(icon_nier, duration=0.5)
#         break
#     pyautogui.sleep(1)
while True :
    icon_nier = pyautogui.locateOnScreen("nier_name.png", confidence=0.7)
    if icon_nier:
        pyautogui.click(icon_nier, duration=0.5)
        pyautogui.sleep(0.5)
        pyautogui.write("2B")
        icon_nier = pyautogui.locateOnScreen("nier_name.png", confidence=0.7)
        pyautogui.click(icon_nier, duration=0.5)
        pyautogui.press("T")
        pyautogui.sleep(0.5)
        pyautogui.press("T")
        break
    pyautogui.sleep(1)    

pyautogui.sleep(10)
pyautogui.press("Z")
pyautogui.sleep(1)  
pyautogui.press("Z")
pyautogui.sleep(1)    
pyautogui.press("T")
pyautogui.sleep(15)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("C")
pyautogui.sleep(30)  
pyautogui.press("Q")
pyautogui.sleep(8)  
pyautogui.press("E")
pyautogui.sleep(5)  
pyautogui.press("E")
pyautogui.sleep(3)  
pyautogui.press("E")
pyautogui.sleep(3)  
pyautogui.press("E")

pyautogui.sleep(3)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("C")

pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")

pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("C")

pyautogui.sleep(10)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("Z")
pyautogui.sleep(1)  
pyautogui.press("T")
pyautogui.sleep(5)  
pyautogui.press("X")


# 확실치 않음
pyautogui.sleep(1)  
pyautogui.press("Z")
pyautogui.sleep(1)  
pyautogui.press("Z")
pyautogui.sleep(3)  
pyautogui.press("B")
pyautogui.sleep(2)  
pyautogui.press("esc")
pyautogui.sleep(2)  
pyautogui.press("esc")


pyautogui.sleep(30)  
pyautogui.press("Y")
pyautogui.sleep(1)  
pyautogui.press("Y")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("V")

pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")
pyautogui.sleep(1)  
pyautogui.press("E")

while True :
    pyautogui.sleep(1)  
    icon_nier = pyautogui.locateOnScreen("nier_collabo.png", confidence=0.7)
    if icon_nier:
        pyautogui.click(icon_nier, duration=0.5)
        break

pyautogui.sleep(1)  
pyautogui.press("B")
pyautogui.sleep(1)  
pyautogui.press("T")
pyautogui.sleep(10)  
pyautogui.press("Z")
pyautogui.sleep(5)  
pyautogui.press("R")

pyautogui.sleep(3)  
pyautogui.press("Q")
pyautogui.sleep(3)  
pyautogui.press("T")
pyautogui.sleep(3)  
pyautogui.press("B")
pyautogui.sleep(3)  
pyautogui.press("B")
pyautogui.sleep(5)  
pyautogui.press("Z")

t=6
while t:
    pyautogui.sleep(3)  
    pyautogui.press("Y")
    pyautogui.sleep(3)  
    pyautogui.press("T")
    pyautogui.sleep(5)  
    pyautogui.press("Z")    
    t -= 1

# %%
pyautogui.sleep(5)  
icon_nier = pyautogui.locateOnScreen("home.png", confidence=0.7)
pyautogui.click(icon_nier, duration=0.5)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_23276/2691425497.py in <module>
#       1 pyautogui.sleep(5)
# ----> 2 icon_nier = pyautogui.locateOnScreen("home.png", confidence=0.7)
#       3 pyautogui.click(icon_nier, duration=0.5)
#
# C:\Python38-64\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
#     176         except pyscreeze.ImageNotFoundException:
#     177             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#
# C:\Python38-64\lib\site-packages\pyautogui\__init__.py in locateOnScreen(*args, **kwargs)
#     211     @raisePyAutoGUIImageNotFoundException
#     212     def locateOnScreen(*args, **kwargs):
# --> 213         return pyscreeze.locateOnScreen(*args, **kwargs)
#     214
#     215     locateOnScreen.__doc__ = pyscreeze.locateOnScreen.__doc__
#
# C:\Python38-64\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     370         try:
#     371             screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 372             retVal = locate(image, screenshotIm, **kwargs)
#     373             try:
#     374                 screenshotIm.fp.close()
#
# C:\Python38-64\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     350     # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     351     kwargs['limit'] = 1
# --> 352     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     353     if len(points) > 0:
#     354         return points[0]
#
# C:\Python38-64\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     204     confidence = float(confidence)
#     205
# --> 206     needleImage = _load_cv2(needleImage, grayscale)
#     207     needleHeight, needleWidth = needleImage.shape[:2]
#     208     haystackImage = _load_cv2(haystackImage, grayscale)
#
# C:\Python38-64\lib\site-packages\pyscreeze\__init__.py in _load_cv2(img, grayscale)
#     167             img_cv = cv2.imread(img, LOAD_COLOR)
#     168         if img_cv is None:
# --> 169             raise IOError("Failed to read %s because file is missing, "
#     170                           "has improper permissions, or is an "
#     171                           "unsupported or invalid format" % img)
#
# OSError: Failed to read home.png because file is missing, has improper permissions, or is an unsupported or invalid format
